# %% [markdown]
# <a href="https://colab.research.google.com/github/vneumannufprbr/PracticasTensorflow/blob/main/PredicSTRNASolarEolDemEspaOkGit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""
Regresión de Series Temporales con TensorFlow/Keras.

Este script es para pronosticar series temporales
de generación de energía (solar, eólica) y demanda total usando redes neuronales.
"""

# --- 1. INSTALACIÓN Y CARGA DE LIBRERÍAS ---
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns

import random as python_random

# Fijar semillas para reproducibilidad
np.random.seed(42)
python_random.seed(42)
tf.random.set_seed(42)

# Configuración de estilo para los gráficos
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (15, 7)

# --- 2. LECTURA Y PREPARACIÓN DE DATOS ---

# Leer y preparar los datos desde la URL
#url = "https://raw.githubusercontent.com/vneumannufprbr/TrabajosRStudio/main/energy_dataset.csv" # Dataset con 3.500 instancias
#data = pd.read_csv(url) # Dataset con 3.500 instancias

url =  "https://raw.githubusercontent.com/vneumannufprbr/Series-Temporales/main/energy_dataset.csv" # Dataset con 35.000 instancias
data = pd.read_csv(url) # Dataset con 35.000 instancias # dtype=dtype_dict,

# Convertir la columna 'time' a formato datetime y ordenar
data['time'] = pd.to_datetime(data['time'], utc=True)
data = data.sort_values('time')

# --- 3. DEFINICIÓN DE PARÁMETROS Y FUNCIONES AUXILIARES ---

# Seleccionar variables objetivo
targets = ["generation solar", "generation wind onshore", "total load actual"]
# Cambiar nombres con puntos por espacios para facilitar el acceso en pandas
data.columns = [col.replace('.', ' ') for col in data.columns]

# Diccionarios para almacenar resultados
results = {}
metrics = {}
histories = {} # Para guardar el historial de entrenamiento

# Parámetros del modelo
WINDOW_SIZE = 24       # Ventana de 24 horas a 7 días (168 h) (MEJOR PARA SOLAR!)
TEST_SIZE = 24   # Con relación 90/10 las métricas son peores
FORECAST_HORIZON = 24  # Horizonte de 24 horas para pronóstico futuro

def create_features(series, window_size):
    """
    Crea un dataset de características (X) y objetivo (y) a partir de una serie temporal.
    """
    X, y = [], []
    for i in range(len(series) - window_size):
        X.append(series[i:(i + window_size)])
        y.append(series[i + window_size])
    return np.array(X), np.array(y)

def calculate_metrics(actual, predicted):
    """
    Calcula e imprime las métricas de evaluación R2, RMSE, MSE y MAE.
    """
    r2 = r2_score(actual, predicted)
    mse = mean_squared_error(actual, predicted) # Calcular MSE
    rmse = np.sqrt(mse) # RMSE es la raíz cuadrada del MSE
    mae = mean_absolute_error(actual, predicted)

    print(f"  R^2: {r2:.4f}")
    print(f"  MSE: {mse:.4f}") # Imprimir MSE
    print(f"  RMSE: {rmse:.4f}")
    print(f"  MAE: {mae:.4f}")


    return {"R2": r2, "MSE": mse, "RMSE": rmse, "MAE": mae} # Incluir MSE en el diccionario

def plot_loss_evolution(history, target_var):
    """
    Grafica la evolución de la pérdida de entrenamiento y validación.
    """
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Pérdida de Entrenamiento') # Translated label
    plt.plot(history.history['val_loss'], label='Pérdida de Validación') # Translated label
    plt.title(f'Evolución de la Función de Pérdida para: {target_var}')
    plt.xlabel('Épocas') # Translated label
    plt.ylabel('Error Cuadrático Medio (MSE)')
    plt.legend()
    plt.show()

# --- 4. ENTRENAMIENTO, EVALUACIÓN Y PRONÓSTICO CON KERAS ---

# Bucle para cada variable objetivo
for target_var in targets:
    print(f"\n{'='*50}")
    print(f"Procesando variable: {target_var}")
    print(f"{'='*50}")

    # Extraer la serie completa y eliminar valores nulos
    series_full = data[target_var].dropna().to_numpy()

    # 1. DIVISIÓN EN ENTRENAMIENTO Y PRUEBA
    train_series = series_full[:-TEST_SIZE]
    test_series_actual = series_full[-TEST_SIZE:]

    # Crear características para el conjunto de entrenamiento
    X_train, y_train = create_features(train_series, WINDOW_SIZE)
    y_train = y_train.reshape(-1, 1) # Asegurar que y_train tenga 2 dimensiones

    # Escalar datos de entrenamiento a [0, 1]
    # Se usa un scaler para las características (X) y otro para el objetivo (y)
    scaler_X = MinMaxScaler()
    X_train_scaled = scaler_X.fit_transform(X_train)

    scaler_y = MinMaxScaler()
    y_train_scaled = scaler_y.fit_transform(y_train)

    # 2. CONSTRUCCIÓN Y ENTRENAMIENTO DEL MODELO DE EVALUACIÓN
    print("\nEntrenando RNA para evaluación...")

    model_eval = Sequential([
        Input(shape=(WINDOW_SIZE,)),  # Capa de entrada con WINDOW_SIZE neuronas
        Dense(64, activation='relu'), # Capa oculta con 64 neuronas
        Dense(32, activation='relu'), # Segunda capa oculta
        Dense(16, activation='relu'), # Tercera capa oculta
        #Dense(8, activation='relu'), # Cuarta capa oculta - Desconectada
        Dense(1)                      # Capa de salida lineal
    ])

    model_eval.compile(optimizer='adam', loss='mean_squared_error')

    # Entrenar el modelo y guardar el historial para graficar la pérdida
    history = model_eval.fit(
        X_train_scaled,
        y_train_scaled,
        epochs=10, # epochs=50
        validation_split=0.2, # Usa el 20% de los datos para validación
        batch_size=32,
        verbose=0 # 0 para no mostrar el log de cada época
    )


    histories[target_var] = history
    print("Entrenamiento completado.")

    # Graficar evolución de la pérdida
    plot_loss_evolution(history, target_var)

    # 3. PREDICCIÓN RECURSIVA EN EL CONJUNTO DE PRUEBA
    test_predictions = []
    current_window = train_series[-WINDOW_SIZE:].tolist()

    for _ in range(TEST_SIZE):
        # Escalar la ventana actual
        window_scaled = scaler_X.transform(np.array(current_window).reshape(1, -1))

        # Predecir el siguiente valor
        pred_scaled = model_eval.predict(window_scaled, verbose=0)

        # Des-escalar la predicción
        pred_actual = scaler_y.inverse_transform(pred_scaled)[0, 0]

        # Guardar la predicción
        test_predictions.append(pred_actual)

        # Actualizar la ventana: eliminar el primer valor y añadir la nueva predicción
        current_window.pop(0)
        current_window.append(pred_actual)

    # Calcular y mostrar métricas de evaluación
    print(f"\nMétricas de Evaluación en Conjunto de Prueba para '{target_var}':")
    metrics[target_var] = calculate_metrics(test_series_actual, test_predictions)

    # 4. PRONÓSTICO FUTURO USANDO TODO EL DATASET
    print("\nRe-entrenando RNA con datos completos para pronóstico futuro...")

    # Preparar datos completos
    X_full, y_full = create_features(series_full, WINDOW_SIZE)
    y_full = y_full.reshape(-1, 1)

    scaler_X_full = MinMaxScaler()
    X_full_scaled = scaler_X_full.fit_transform(X_full)

    scaler_y_full = MinMaxScaler()
    y_full_scaled = scaler_y_full.fit_transform(y_full)

    # Construir y entrenar el modelo final
    model_final = Sequential([
        Input(shape=(WINDOW_SIZE,)),
        Dense(64, activation='relu'), # Capa oculta con 64 neuronas
        Dense(32, activation='relu'), # Segunda capa oculta
        Dense(16, activation='relu'), # Tercera capa oculta
        #Dense(8, activation='relu'), # Cuarta capa oculta - Desconectada
        Dense(1)                      # Capa de salida lineal
    ])
    model_final.compile(optimizer='adam', loss='mean_squared_error')
    model_final.fit(X_full_scaled, y_full_scaled, epochs=50, batch_size=32, verbose=1)

    print("Entrenamiento completado.")

    # Generar pronóstico futuro
    future_predictions = []
    last_window_full = series_full[-WINDOW_SIZE:].tolist()

    for _ in range(FORECAST_HORIZON):
        window_scaled = scaler_X_full.transform(np.array(last_window_full).reshape(1, -1))
        pred_scaled = model_final.predict(window_scaled, verbose=0)
        pred_actual = scaler_y_full.inverse_transform(pred_scaled)[0, 0]
        future_predictions.append(pred_actual)
        last_window_full.pop(0)
        last_window_full.append(pred_actual)

    results[target_var] = future_predictions

# --- 5. VISUALIZACIÓN DE RESULTADOS ---

# Crear DataFrame con los pronósticos
last_date = data['time'].iloc[-1]
future_dates = pd.to_datetime([last_date + pd.DateOffset(hours=i) for i in range(1, FORECAST_HORIZON + 1)])

forecast_df = pd.DataFrame({
    'time': future_dates,
    'solar': results['generation solar'],
    'wind_onshore': results['generation wind onshore'],
    'total_load': results['total load actual']
})

# Graficar los pronósticos
plt.figure(figsize=(18, 12))
plt.suptitle('Pronóstico a 24 Horas con Redes Neuronales (Keras)', fontsize=20, y=0.95)

# Gráfico para Generación Solar
plt.subplot(3, 1, 1)
plt.plot(forecast_df['time'], forecast_df['solar'], label='Pronóstico Solar', color='orange', marker='.')
plt.title('Generación Solar')
plt.ylabel('Valor')
plt.legend()
plt.xticks(rotation=45)

# Gráfico para Generación Eólica
plt.subplot(3, 1, 2)
plt.plot(forecast_df['time'], forecast_df['wind_onshore'], label='Pronóstico Eólico', color='blue', marker='.')
plt.title('Generación Eólica (Onshore)')
plt.ylabel('Valor')
plt.legend()
plt.xticks(rotation=45)

# Gráfico para Demanda Total
plt.subplot(3, 1, 3)
plt.plot(forecast_df['time'], forecast_df['total_load'], label='Pronóstico Demanda Total', color='green', marker='.')
plt.title('Demanda Total')
plt.xlabel('Fecha y Hora')
plt.ylabel('Valor')
plt.legend()
plt.xticks(rotation=45)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
# Out:
# ==================================================
# Procesando variable: generation solar
# ==================================================
#
# Entrenando RNA para evaluación...
# Entrenamiento completado.
# Métricas de Evaluación en Conjunto de Prueba para 'generation solar':
#   R^2: 0.9781
#   MSE: 50409.2022
#   RMSE: 224.5199
#   MAE: 145.5501
#
# Re-entrenando RNA con datos completos para pronóstico futuro...
# Epoch 1/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0062
# Epoch 2/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 8.7065e-04
# Epoch 3/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.7438e-04
# Epoch 4/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 7.2322e-04
# Epoch 5/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 6.8758e-04
# Epoch 6/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 6.5766e-04
# Epoch 7/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.4081e-04
# Epoch 8/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.1525e-04
# Epoch 9/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 6.0967e-04
# Epoch 10/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 5.9636e-04
# Epoch 11/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 5.8232e-04
# Epoch 12/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 5.7364e-04
# Epoch 13/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 5.6939e-04
# Epoch 14/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 5.6284e-04
# Epoch 15/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 5.5554e-04
# Epoch 16/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 5.4501e-04
# Epoch 17/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 5.4223e-04
# Epoch 18/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 5.3613e-04
# Epoch 19/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 5.3004e-04
# Epoch 20/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 5.2033e-04
# Epoch 21/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 5.1987e-04
# Epoch 22/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 5.1802e-04
# Epoch 23/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 5.1598e-04
# Epoch 24/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 5.0519e-04
# Epoch 25/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 5.0176e-04
# Epoch 26/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 5.0068e-04
# Epoch 27/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.9519e-04
# Epoch 28/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 4.9351e-04
# Epoch 29/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.9274e-04
# Epoch 30/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9187e-04
# Epoch 31/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.8362e-04
# Epoch 32/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 4.8259e-04
# Epoch 33/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 4.8198e-04
# Epoch 34/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 4.7818e-04
# Epoch 35/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 4.7223e-04
# Epoch 36/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.6804e-04
# Epoch 37/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 4.6926e-04
# Epoch 38/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.6402e-04
# Epoch 39/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 4.5771e-04
# Epoch 40/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.5961e-04
# Epoch 41/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.5772e-04
# Epoch 42/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 4.5490e-04
# Epoch 43/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 4.5393e-04
# Epoch 44/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.5395e-04
# Epoch 45/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.5068e-04
# Epoch 46/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 4.4807e-04
# Epoch 47/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.4559e-04
# Epoch 48/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.4724e-04
# Epoch 49/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 4.4605e-04
# Epoch 50/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.4497e-04
# Entrenamiento completado.
#
# ==================================================
# Procesando variable: generation wind onshore
# ==================================================
#
# Entrenando RNA para evaluación...
# Entrenamiento completado.
# Métricas de Evaluación en Conjunto de Prueba para 'generation wind onshore':
#   R^2: -6.4532
#   MSE: 3016128.4305
#   RMSE: 1736.7004
#   MAE: 1487.7418
#
# Re-entrenando RNA con datos completos para pronóstico futuro...
# Epoch 1/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0121
# Epoch 2/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0015
# Epoch 3/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0014
# Epoch 4/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0014
# Epoch 5/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0014
# Epoch 6/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0014
# Epoch 7/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0014
# Epoch 8/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0014
# Epoch 9/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0014
# Epoch 10/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0014
# Epoch 11/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0014
# Epoch 12/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0014
# Epoch 13/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0013
# Epoch 14/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0013
# Epoch 15/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0013
# Epoch 16/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0013
# Epoch 17/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0013
# Epoch 18/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0013
# Epoch 19/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0013
# Epoch 20/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0013
# Epoch 21/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0013
# Epoch 22/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0013
# Epoch 23/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0013
# Epoch 24/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0013
# Epoch 25/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0013
# Epoch 26/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0013
# Epoch 27/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0013
# Epoch 28/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0013
# Epoch 29/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0013
# Epoch 30/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0013
# Epoch 31/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0013
# Epoch 32/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0013
# Epoch 33/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0013
# Epoch 34/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0013
# Epoch 35/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0013
# Epoch 36/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0013
# Epoch 37/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0013
# Epoch 38/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0013
# Epoch 39/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0013
# Epoch 40/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0013
# Epoch 41/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0013
# Epoch 42/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0013
# Epoch 43/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0013
# Epoch 44/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0013
# Epoch 45/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0012
# Epoch 46/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0012
# Epoch 47/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0012
# Epoch 48/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0013
# Epoch 49/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0012
# Epoch 50/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0012
# Entrenamiento completado.
#
# ==================================================
# Procesando variable: total load actual
# ==================================================
#
# Entrenando RNA para evaluación...
# Entrenamiento completado.
# Métricas de Evaluación en Conjunto de Prueba para 'total load actual':
#   R^2: -0.0513
#   MSE: 12254898.6610
#   RMSE: 3500.6997
#   MAE: 2804.7113
#
# Re-entrenando RNA con datos completos para pronóstico futuro...
# Epoch 1/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0166
# Epoch 2/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0011
# Epoch 3/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 9.1129e-04
# Epoch 4/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 8.2732e-04
# Epoch 5/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 7.7382e-04
# Epoch 6/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 7.3527e-04
# Epoch 7/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 7.0464e-04
# Epoch 8/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.8480e-04
# Epoch 9/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 6.6195e-04
# Epoch 10/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 6.4403e-04
# Epoch 11/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 6.2800e-04
# Epoch 12/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 6.2036e-04
# Epoch 13/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 6.0829e-04
# Epoch 14/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 6.0330e-04
# Epoch 15/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 5.9592e-04
# Epoch 16/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 5.8978e-04
# Epoch 17/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.8228e-04
# Epoch 18/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 5.7329e-04
# Epoch 19/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 5.6678e-04
# Epoch 20/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 5.6340e-04
# Epoch 21/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 5.5536e-04
# Epoch 22/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 5.5591e-04
# Epoch 23/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 5.5290e-04
# Epoch 24/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 5.4552e-04
# Epoch 25/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 5.3824e-04
# Epoch 26/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 5.3749e-04
# Epoch 27/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 5.3046e-04
# Epoch 28/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 5.2529e-04
# Epoch 29/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 5.2455e-04
# Epoch 30/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 5.2129e-04
# Epoch 31/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 5.0734e-04
# Epoch 32/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 5.0378e-04
# Epoch 33/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 5.0341e-04
# Epoch 34/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 4.9888e-04
# Epoch 35/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9526e-04
# Epoch 36/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9182e-04
# Epoch 37/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.8831e-04
# Epoch 38/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9000e-04
# Epoch 39/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.8033e-04
# Epoch 40/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.8184e-04
# Epoch 41/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.7910e-04
# Epoch 42/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.7520e-04
# Epoch 43/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.7685e-04
# Epoch 44/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.6930e-04
# Epoch 45/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 4.6733e-04
# Epoch 46/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.6790e-04
# Epoch 47/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.6548e-04
# Epoch 48/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.6321e-04
# Epoch 49/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.6377e-04
# Epoch 50/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 4.5839e-04
# Entrenamiento completado.
