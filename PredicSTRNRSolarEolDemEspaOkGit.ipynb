# %% [markdown]
# <a href="https://colab.research.google.com/github/vneumannufprbr/PracticasTensorflow/blob/main/PredicSTRNRSolarEolDemEspaOkGit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Las modificaciones principales efectuadas en el notebook con el modelo de Red Neuronal Artificial (RNA) a este de Red Neuronal Recurrente (RNR) son en los siguientes aspectos:
#
# 1. Importar la capa SimpleRNN de Keras: En lugar de solo usar capas Dense (que son para RNA), importar la capa SimpleRNN para construir tu modelo recurrente.
# 2. Dar forma a los datos de entrada para la RNR: Las RNs tradicionales (Dense)
# esperan entradas 2D (muestras, características), mientras que las RNRs esperan entradas 3D (muestras, pasos de tiempo, características). Remodelar los datos  ( X_train_scaled y X_full_scaled) a la forma (número_de_muestras, tamaño_de_la_ventana, 1).
# 3. Construir el modelo con capas SimpleRNN: En la definición del modelo de Keras (Sequential), reemplazar la primera capa Dense por una capa SimpleRNN.
# 4. Considerar la naturaleza secuencial para la predicción: En el caso de la predicción futura, el enfoque recursivo que ya tienes en tu cuaderno es apropiado para las RNRs, donde cada predicción se basa en la ventana anterior (que incluye las predicciones pasadas).
#
# Las líneas de código que implementan las modificaciones para usar una RNR Simple son:
#
# 1. Importar la capa SimpleRNN: En la celda de código con ID ohmFDM57lUOH, la línea:
# from tensorflow.keras.layers import Dense, Input, SimpleRNN # Importar SimpleRNN
# importa la capa necesaria.
#
# 2. Dar forma a los datos de entrada para la RNR: En la celda de código con ID ohmFDM57lUOH, dentro del bucle for target_var in targets:, encontrarás las siguientes líneas que remodelan los datos a la forma 3D requerida por la RNR:
# X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], X_train_scaled.shape[1], 1))
# y más abajo, para los datos completos:
# X_full_scaled = X_full_scaled.reshape((X_full_scaled.shape[0], X_full_scaled.shape[1], 1))
#
# 3. Construir el modelo con capas SimpleRNN: En la celda de código con ID ohmFDM57lUOH, dentro del bucle for target_var in targets:, la definición del modelo model_eval incluye la capa SimpleRNN:
# model_eval = Sequential([
#     Input(shape=(WINDOW_SIZE, 1)),  # Capa de entrada para SimpleRNN
#     SimpleRNN(128, activation='relu'), # Capa SimpleRNN con 128 unidades
#     Dense(32, activation='relu'), # Segunda capa oculta
#     Dense(16, activation='relu'), # Tercera capa oculta
#     Dense(1)                      # Capa de salida lineal
# ])

# %%
# -*- coding: utf-8 -*-
"""
Regresión de Series Temporales con TensorFlow/Keras.

Este script es para pronosticar series temporales
de generación de energía (solar, eólica) y demanda total usando redes neuronales.
"""

# --- 1. INSTALACIÓN Y CARGA DE LIBRERÍAS ---
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, SimpleRNN # Importar SimpleRNN
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns

import random as python_random

# Fijar semillas para reproducibilidad
np.random.seed(42)
python_random.seed(42)
tf.random.set_seed(42)

# Configuración de estilo para los gráficos
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (15, 7)

# --- 2. LECTURA Y PREPARACIÓN DE DATOS ---

# Leer y preparar los datos desde la URL
#url = "https://raw.githubusercontent.com/vneumannufprbr/TrabajosRStudio/main/energy_dataset.csv" # Dataset con 3.500 instancias
#data = pd.read_csv(url) # Dataset con 3.500 instancias

url =  "https://raw.githubusercontent.com/vneumannufprbr/Series-Temporales/main/energy_dataset.csv" # Dataset con 35.000 instancias
data = pd.read_csv(url) # Dataset con 35.000 instancias # dtype=dtype_dict,

# Convertir la columna 'time' a formato datetime y ordenar
data['time'] = pd.to_datetime(data['time'], utc=True)
data = data.sort_values('time')

# --- 3. DEFINICIÓN DE PARÁMETROS Y FUNCIONES AUXILIARES ---

# Seleccionar variables objetivo
targets = ["generation solar", "generation wind onshore", "total load actual"]
# Cambiar nombres con puntos por espacios para facilitar el acceso en pandas
data.columns = [col.replace('.', ' ') for col in data.columns]

# Diccionarios para almacenar resultados
results = {}
metrics = {}
histories = {} # Para guardar el historial de entrenamiento

# Parámetros del modelo
WINDOW_SIZE = 24       # Ventana de 24 horas a 7 días (168 h) (MEJOR PARA SOLAR!)
TEST_SIZE = int(0.1 * len(data))         # Relación 90/10 para Dataset de entrenamiento
FORECAST_HORIZON = 24  # Horizonte de 24 horas para pronóstico futuro

def create_features(series, window_size):
    """
    Crea un dataset de características (X) y objetivo (y) a partir de una serie temporal.
    """
    X, y = [], []
    for i in range(len(series) - window_size):
        X.append(series[i:(i + window_size)])
        y.append(series[i + window_size])
    return np.array(X), np.array(y)

def calculate_metrics(actual, predicted):
    """
    Calcula e imprime las métricas de evaluación R2, RMSE, MSE y MAE.
    """
    r2 = r2_score(actual, predicted)
    mse = mean_squared_error(actual, predicted) # Calcular MSE
    rmse = np.sqrt(mse) # RMSE es la raíz cuadrada del MSE
    mae = mean_absolute_error(actual, predicted)

    print(f"  R^2: {r2:.4f}")
    print(f"  MSE: {mse:.4f}") # Imprimir MSE
    print(f"  RMSE: {rmse:.4f}")
    print(f"  MAE: {mae:.4f}")


    return {"R2": r2, "MSE": mse, "RMSE": rmse, "MAE": mae} # Incluir MSE en el diccionario

def plot_loss_evolution(history, target_var):
    """
    Grafica la evolución de la pérdida de entrenamiento y validación.
    """
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Pérdida de Entrenamiento') # Translated label
    plt.plot(history.history['val_loss'], label='Pérdida de Validación') # Translated label
    plt.title(f'Evolución de la Función de Pérdida para: {target_var}')
    plt.xlabel('Épocas') # Translated label
    plt.ylabel('Error Cuadrático Medio (MSE)')
    plt.legend()
    plt.show()

# --- 4. ENTRENAMIENTO, EVALUACIÓN Y PRONÓSTICO CON KERAS ---

# Bucle para cada variable objetivo
for target_var in targets:
    print(f"\n{'='*50}")
    print(f"Procesando variable: {target_var}")
    print(f"{'='*50}")

    # Extraer la serie completa y eliminar valores nulos
    series_full = data[target_var].dropna().to_numpy()

    # 1. DIVISIÓN EN ENTRENAMIENTO Y PRUEBA
    train_series = series_full[:-TEST_SIZE]
    test_series_actual = series_full[-TEST_SIZE:]

    # Crear características para el conjunto de entrenamiento
    X_train, y_train = create_features(train_series, WINDOW_SIZE)
    y_train = y_train.reshape(-1, 1) # Asegurar que y_train tenga 2 dimensiones

    # Escalar datos de entrenamiento a [0, 1]
    # Se usa un scaler para las características (X) y otro para el objetivo (y)
    scaler_X = MinMaxScaler()
    X_train_scaled = scaler_X.fit_transform(X_train)

    scaler_y = MinMaxScaler()
    y_train_scaled = scaler_y.fit_transform(y_train)

    # Las RNNs esperan una entrada 3D (muestras, pasos de tiempo, características)
    X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], X_train_scaled.shape[1], 1))


    # 2. CONSTRUCCIÓN Y ENTRENAMIENTO DEL MODELO DE EVALUACIÓN
    print("\nEntrenando RNR Simple para evaluación...")

    model_eval = Sequential([
        Input(shape=(WINDOW_SIZE, 1)),  # Capa de entrada para SimpleRNN
        SimpleRNN(128, activation='relu'), # Capa SimpleRNN con 128 unidades
        Dense(32, activation='relu'), # Segunda capa oculta
        Dense(16, activation='relu'), # Tercera capa oculta
        Dense(1)                      # Capa de salida lineal
    ])

    model_eval.compile(optimizer='adam', loss='mean_squared_error')

    # Entrenar el modelo y guardar el historial para graficar la pérdida
    history = model_eval.fit(
        X_train_scaled,
        y_train_scaled,
        epochs=10, # epochs=50
        validation_split=0.2, # Usa el 20% de los datos para validación
        batch_size=32,
        verbose=0 # 0 para no mostrar el log de cada época
    )


    histories[target_var] = history
    print("Entrenamiento completado.")

    # Graficar evolución de la pérdida
    plot_loss_evolution(history, target_var)

    # 3. PREDICCIÓN RECURSIVA EN EL CONJUNTO DE PRUEBA
    test_predictions = []
    current_window = train_series[-WINDOW_SIZE:].tolist()

    for _ in range(TEST_SIZE):
        # Escalar la ventana actual y darle la forma 3D
        window_scaled = scaler_X.transform(np.array(current_window).reshape(1, -1))
        window_scaled = window_scaled.reshape((window_scaled.shape[0], window_scaled.shape[1], 1))


        # Predecir el siguiente valor
        pred_scaled = model_eval.predict(window_scaled, verbose=0)

        # Des-escalar la predicción
        pred_actual = scaler_y.inverse_transform(pred_scaled)[0, 0]

        # Guardar la predicción
        test_predictions.append(pred_actual)

        # Actualizar la ventana: eliminar el primer valor y añadir la nueva predicción
        current_window.pop(0)
        current_window.append(pred_actual)

    # Calcular y mostrar métricas de evaluación
    print(f"\nMétricas de Evaluación en Conjunto de Prueba para '{target_var}':")
    metrics[target_var] = calculate_metrics(test_series_actual, test_predictions)

    # 4. PRONÓSTICO FUTURO USANDO TODO EL DATASET
    print("\nRe-entrenando RNR Simple con datos completos para pronóstico futuro...")

    # Preparar datos completos
    X_full, y_full = create_features(series_full, WINDOW_SIZE)
    y_full = y_full.reshape(-1, 1)

    scaler_X_full = MinMaxScaler()
    X_full_scaled = scaler_X_full.fit_transform(X_full)

    scaler_y_full = MinMaxScaler()
    y_full_scaled = scaler_y_full.fit_transform(y_full)

    # Dar forma 3D a los datos completos para la RNR Simple
    X_full_scaled = X_full_scaled.reshape((X_full_scaled.shape[0], X_full_scaled.shape[1], 1))


    # Construir y entrenar el modelo final
    model_final = Sequential([
        Input(shape=(WINDOW_SIZE, 1)), # Capa de entrada para SimpleRNN
        SimpleRNN(128, activation='relu'), # Capa SimpleRNN con 128 unidades
        Dense(32, activation='relu'), # Segunda capa oculta
        Dense(16, activation='relu'), # Tercera capa oculta
        Dense(1)                      # Capa de salida lineal
    ])
    model_final.compile(optimizer='adam', loss='mean_squared_error')
    model_final.fit(X_full_scaled, y_full_scaled, epochs=50, batch_size=32, verbose=1)

    print("Entrenamiento completado.")

    # Generar pronóstico futuro
    future_predictions = []
    last_window_full = series_full[-WINDOW_SIZE:].tolist()

    for _ in range(FORECAST_HORIZON):
        # Escalar la última ventana completa y darle forma 3D
        window_scaled = scaler_X_full.transform(np.array(last_window_full).reshape(1, -1))
        window_scaled = window_scaled.reshape((window_scaled.shape[0], window_scaled.shape[1], 1))

        pred_scaled = model_final.predict(window_scaled, verbose=0)
        pred_actual = scaler_y_full.inverse_transform(pred_scaled)[0, 0]
        future_predictions.append(pred_actual)
        last_window_full.pop(0)
        last_window_full.append(pred_actual)

    results[target_var] = future_predictions

# --- 5. VISUALIZACIÓN DE RESULTADOS ---

# Crear DataFrame con los pronósticos
last_date = data['time'].iloc[-1]
future_dates = pd.to_datetime([last_date + pd.DateOffset(hours=i) for i in range(1, FORECAST_HORIZON + 1)])

forecast_df = pd.DataFrame({
    'time': future_dates,
    'solar': results['generation solar'],
    'wind_onshore': results['generation wind onshore'],
    'total_load': results['total load actual']
})

# Graficar los pronósticos
plt.figure(figsize=(18, 12))
plt.suptitle('Pronóstico a 24 Horas con Redes Neuronales Recurrentes Simples (Keras)', fontsize=20, y=0.95) # Actualizar título

# Gráfico para Generación Solar
plt.subplot(3, 1, 1)
plt.plot(forecast_df['time'], forecast_df['solar'], label='Pronóstico Solar', color='orange', marker='.')
plt.title('Generación Solar')
plt.ylabel('Valor')
plt.legend()
plt.xticks(rotation=45)

# Gráfico para Generación Eólica
plt.subplot(3, 1, 2)
plt.plot(forecast_df['time'], forecast_df['wind_onshore'], label='Pronóstico Eólico', color='blue', marker='.')
plt.title('Generación Eólica (Onshore)')
plt.ylabel('Valor')
plt.legend()
plt.xticks(rotation=45)

# Gráfico para Demanda Total
plt.subplot(3, 1, 3)
plt.plot(forecast_df['time'], forecast_df['total_load'], label='Pronóstico Demanda Total', color='green', marker='.')
plt.title('Demanda Total')
plt.xlabel('Fecha y Hora')
plt.ylabel('Valor')
plt.legend()
plt.xticks(rotation=45)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
# Out:
# ==================================================
# Procesando variable: generation solar
# ==================================================
#
# Entrenando RNR Simple para evaluación...
# Entrenamiento completado.
# Métricas de Evaluación en Conjunto de Prueba para 'generation solar':
#   R^2: 0.9790
#   MSE: 48214.1258
#   RMSE: 219.5772
#   MAE: 141.3132
#
# Re-entrenando RNR Simple con datos completos para pronóstico futuro...
# Epoch 1/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 0.0086
# Epoch 2/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 6.9511e-04
# Epoch 3/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 6.2077e-04
# Epoch 4/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 5.9936e-04
# Epoch 5/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 5.8204e-04
# Epoch 6/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 5.6942e-04
# Epoch 7/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 5.5267e-04
# Epoch 8/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 5.4965e-04
# Epoch 9/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 5.3177e-04
# Epoch 10/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 5.1540e-04
# Epoch 11/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 5.2743e-04
# Epoch 12/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 4.9639e-04
# Epoch 13/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 5.0397e-04
# Epoch 14/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 4.9829e-04
# Epoch 15/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 4.7598e-04
# Epoch 16/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 4.7058e-04
# Epoch 17/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 4.7678e-04
# Epoch 18/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 5.0542e-04
# Epoch 19/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 4.6566e-04
# Epoch 20/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 4.6234e-04
# Epoch 21/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 4.8014e-04
# Epoch 22/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 4.6666e-04
# Epoch 23/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 4.5193e-04
# Epoch 24/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 4.4705e-04
# Epoch 25/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 4.4437e-04
# Epoch 26/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 4.4788e-04
# Epoch 27/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 4.6351e-04
# Epoch 28/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 4.4184e-04
# Epoch 29/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 4.4047e-04
# Epoch 30/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 4.3670e-04
# Epoch 31/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 4.2989e-04
# Epoch 32/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 4.3819e-04
# Epoch 33/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 4.2816e-04
# Epoch 34/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 4.2919e-04
# Epoch 35/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 4.2859e-04
# Epoch 36/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 4.3271e-04
# Epoch 37/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 4.4281e-04
# Epoch 38/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 4.2759e-04
# Epoch 39/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 4.1417e-04
# Epoch 40/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 4.1884e-04
# Epoch 41/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 4.2460e-04
# Epoch 42/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 4.1956e-04
# Epoch 43/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 4.2134e-04
# Epoch 44/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 4.1453e-04
# Epoch 45/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 4.1007e-04
# Epoch 46/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 4.1357e-04
# Epoch 47/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 4.1603e-04
# Epoch 48/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 4.1186e-04
# Epoch 49/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 4.1445e-04
# Epoch 50/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 4.0149e-04
# Entrenamiento completado.
#
# ==================================================
# Procesando variable: generation wind onshore
# ==================================================
#
# Entrenando RNR Simple para evaluación...
# Entrenamiento completado.
# Métricas de Evaluación en Conjunto de Prueba para 'generation wind onshore':
#   R^2: -96.2753
#   MSE: 39364905.3378
#   RMSE: 6274.1458
#   MAE: 5193.2666
#
# Re-entrenando RNR Simple con datos completos para pronóstico futuro...
# Epoch 1/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0101
# Epoch 2/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0013
# Epoch 3/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0013
# Epoch 4/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0013
# Epoch 5/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0013
# Epoch 6/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Epoch 7/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Epoch 8/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 0.0012
# Epoch 9/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0012
# Epoch 10/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0012
# Epoch 11/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Epoch 12/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0012
# Epoch 13/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 0.0012
# Epoch 14/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0012
# Epoch 15/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0012
# Epoch 16/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Epoch 17/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Epoch 18/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0012
# Epoch 19/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0012
# Epoch 20/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Epoch 21/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Epoch 22/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0012
# Epoch 23/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Epoch 24/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Epoch 25/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0012
# Epoch 26/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0012
# Epoch 27/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0012
# Epoch 28/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Epoch 29/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0012
# Epoch 30/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0012
# Epoch 31/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Epoch 32/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Epoch 33/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0012
# Epoch 34/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0012
# Epoch 35/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Epoch 36/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0012
# Epoch 37/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0012
# Epoch 38/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Epoch 39/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0012
# Epoch 40/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0012
# Epoch 41/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0012
# Epoch 42/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0012
# Epoch 43/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Epoch 44/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0012
# Epoch 45/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0012
# Epoch 46/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0012
# Epoch 47/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Epoch 48/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0012
# Epoch 49/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 0.0012
# Epoch 50/50
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Entrenamiento completado.
#
# ==================================================
# Procesando variable: total load actual
# ==================================================
#
# Entrenando RNR Simple para evaluación...
# Entrenamiento completado.
# Métricas de Evaluación en Conjunto de Prueba para 'total load actual':
#   R^2: -2.4781
#   MSE: 40544314.2215
#   RMSE: 6367.4417
#   MAE: 5992.8455
#
# Re-entrenando RNR Simple con datos completos para pronóstico futuro...
# Epoch 1/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0100
# Epoch 2/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 8.4216e-04
# Epoch 3/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 7.4094e-04
# Epoch 4/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 6.8762e-04
# Epoch 5/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 6.5937e-04
# Epoch 6/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 6.4424e-04
# Epoch 7/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 6.0905e-04
# Epoch 8/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 5.9254e-04
# Epoch 9/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 5.6789e-04
# Epoch 10/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 5.1831e-04
# Epoch 11/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 4.9516e-04
# Epoch 12/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 4.7460e-04
# Epoch 13/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 4.6954e-04
# Epoch 14/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 4.5219e-04
# Epoch 15/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 4.3931e-04
# Epoch 16/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 4.3983e-04
# Epoch 17/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 4.2426e-04
# Epoch 18/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 4.2527e-04
# Epoch 19/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 4.1309e-04
# Epoch 20/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 4.1293e-04
# Epoch 21/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 4.1723e-04
# Epoch 22/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 4.0392e-04
# Epoch 23/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 4.0613e-04
# Epoch 24/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 4.0083e-04
# Epoch 25/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 3.9010e-04
# Epoch 26/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 3.9327e-04
# Epoch 27/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 3.8314e-04
# Epoch 28/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 3.7595e-04
# Epoch 29/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 3.8219e-04
# Epoch 30/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - loss: 3.7087e-04
# Epoch 31/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 3.9042e-04
# Epoch 32/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 3.7247e-04
# Epoch 33/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 3.6224e-04
# Epoch 34/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 3.5818e-04
# Epoch 35/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 3.6638e-04
# Epoch 36/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 3.6166e-04
# Epoch 37/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 3.7294e-04
# Epoch 38/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - loss: 3.6062e-04
# Epoch 39/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - loss: 3.5250e-04
# Epoch 40/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 3.5021e-04
# Epoch 41/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 3.4511e-04
# Epoch 42/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 3.4158e-04
# Epoch 43/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 3.4962e-04
# Epoch 44/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 3.4473e-04
# Epoch 45/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 3.6139e-04
# Epoch 46/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - loss: 3.3764e-04
# Epoch 47/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 3.4533e-04
# Epoch 48/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 3.3827e-04
# Epoch 49/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 3.3582e-04
# Epoch 50/50
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 3.4352e-04
# Entrenamiento completado.
